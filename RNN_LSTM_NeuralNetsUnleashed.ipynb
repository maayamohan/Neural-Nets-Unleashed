# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import os
import time

# %%
text = """
To be, or not to be, that is the question:
Whether 'tis nobler in the mind to suffer
The slings and arrows of outrageous fortune,
Or to take Arms against a Sea of troubles...
"""

# %%
chars = sorted(list(set(text)))
char_to_idx = {ch: i for i, ch in enumerate(chars)}
idx_to_char = {i: ch for i, ch in enumerate(chars)}
n_chars = len(chars)

# %%
class TextDataset(Dataset):
    def __init__(self, text, sequence_length=50):
        self.sequence_length = sequence_length
        self.text = text
        self.total_sequences = len(text) - sequence_length

    def __len__(self):
        return self.total_sequences

    def __getitem__(self, idx):
        sequence = self.text[idx:idx + self.sequence_length]
        target = self.text[idx + 1:idx + self.sequence_length + 1]

        x = torch.tensor([char_to_idx[ch] for ch in sequence], dtype=torch.long)
        y = torch.tensor([char_to_idx[ch] for ch in target], dtype=torch.long)

        return x, y

# %%
class SimpleRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(SimpleRNN, self).__init__()
        self.hidden_size = hidden_size
        self.rnn = torch.nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden=None):
        x = F.one_hot(x, num_classes=n_chars).float()
        output, hidden = self.rnn(x, hidden)
        output = self.fc(output)
        return output, hidden

    def init_hidden(self, batch_size):
        return torch.zeros(1, batch_size, self.hidden_size)

# %%
def train_model(model, dataloader, criterion, optimizer, epochs=10):
    model.train()

    for epoch in range(epochs):
        total_loss = 0
        for batch_idx, (x, y) in enumerate(dataloader):
            hidden = model.init_hidden(x.size(0))

            output, hidden = model(x, hidden)
            loss = criterion(output.view(-1, n_chars), y.view(-1))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        print(f'Epoch {epoch+1}, Loss: {total_loss/len(dataloader):.4f}')

# %%
def generate_text(model, seed_text, length=100, temperature=0.8):
    model.eval()
    current_text = seed_text
    hidden = model.init_hidden(1)

    with torch.no_grad():
        for _ in range(length):
            x = torch.tensor([char_to_idx[ch] for ch in current_text[-50:]], dtype=torch.long).unsqueeze(0)
            output, hidden = model(x, hidden)
            probs = F.softmax(output[0, -1] / temperature, dim=0)
            next_char_idx = torch.multinomial(probs, 1).item()
            current_text += idx_to_char[next_char_idx]

    return current_text

# %%
sequence_length = 50
hidden_size = 128
batch_size = 32

dataset = TextDataset(text, sequence_length)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

model = SimpleRNN(n_chars, hidden_size, n_chars)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)


train_model(model, dataloader, criterion, optimizer, epochs=1000)
# Out:
# Epoch 1, Loss: 3.1272
# Epoch 2, Loss: 2.7831
# Epoch 3, Loss: 2.4277
# Epoch 4, Loss: 1.9550
# Epoch 5, Loss: 1.4768
# Epoch 6, Loss: 1.0700
# Epoch 7, Loss: 0.7386
# Epoch 8, Loss: 0.5029
# Epoch 9, Loss: 0.3520
# Epoch 10, Loss: 0.2539
# Epoch 11, Loss: 0.1972
# Epoch 12, Loss: 0.1568
# Epoch 13, Loss: 0.1342
# Epoch 14, Loss: 0.1158
# Epoch 15, Loss: 0.1025
# Epoch 16, Loss: 0.0922
# Epoch 17, Loss: 0.0848
# Epoch 18, Loss: 0.0795
# Epoch 19, Loss: 0.0748
# Epoch 20, Loss: 0.0717
# Epoch 21, Loss: 0.0692
# Epoch 22, Loss: 0.0668
# Epoch 23, Loss: 0.0650
# Epoch 24, Loss: 0.0636
# Epoch 25, Loss: 0.0622
# Epoch 26, Loss: 0.0607
# Epoch 27, Loss: 0.0601
# Epoch 28, Loss: 0.0586
# Epoch 29, Loss: 0.0584
# Epoch 30, Loss: 0.0571
# Epoch 31, Loss: 0.0568
# Epoch 32, Loss: 0.0570
# Epoch 33, Loss: 0.0557
# Epoch 34, Loss: 0.0549
# Epoch 35, Loss: 0.0543
# Epoch 36, Loss: 0.0547
# Epoch 37, Loss: 0.0539
# Epoch 38, Loss: 0.0537
# Epoch 39, Loss: 0.0530
# Epoch 40, Loss: 0.0526
# Epoch 41, Loss: 0.0523
# Epoch 42, Loss: 0.0519
# Epoch 43, Loss: 0.0512
# Epoch 44, Loss: 0.0510
# Epoch 45, Loss: 0.0506
# Epoch 46, Loss: 0.0504
# Epoch 47, Loss: 0.0502
# Epoch 48, Loss: 0.0498
# Epoch 49, Loss: 0.0497
# Epoch 50, Loss: 0.0499
# Epoch 51, Loss: 0.0495
# Epoch 52, Loss: 0.0495
# Epoch 53, Loss: 0.0492
# Epoch 54, Loss: 0.0492
# Epoch 55, Loss: 0.0487
# Epoch 56, Loss: 0.0485
# Epoch 57, Loss: 0.0482
# Epoch 58, Loss: 0.0484
# Epoch 59, Loss: 0.0487
# Epoch 60, Loss: 0.0479
# Epoch 61, Loss: 0.0480
# Epoch 62, Loss: 0.0478
# Epoch 63, Loss: 0.0480
# Epoch 64, Loss: 0.0473
# Epoch 65, Loss: 0.0475
# Epoch 66, Loss: 0.0474
# Epoch 67, Loss: 0.0475
# Epoch 68, Loss: 0.0469
# Epoch 69, Loss: 0.0471
# Epoch 70, Loss: 0.0464
# Epoch 71, Loss: 0.0468
# Epoch 72, Loss: 0.0466
# Epoch 73, Loss: 0.0466
# Epoch 74, Loss: 0.0464
# Epoch 75, Loss: 0.0467
# Epoch 76, Loss: 0.0459
# Epoch 77, Loss: 0.0463
# Epoch 78, Loss: 0.0462
# Epoch 79, Loss: 0.0458
# Epoch 80, Loss: 0.0466
# Epoch 81, Loss: 0.0463
# Epoch 82, Loss: 0.0464
# Epoch 83, Loss: 0.0476
# Epoch 84, Loss: 0.0461
# Epoch 85, Loss: 0.0460
# Epoch 86, Loss: 0.0455
# Epoch 87, Loss: 0.0462
# Epoch 88, Loss: 0.0461
# Epoch 89, Loss: 0.0457
# Epoch 90, Loss: 0.0454
# Epoch 91, Loss: 0.0454
# Epoch 92, Loss: 0.0452
# Epoch 93, Loss: 0.0452
# Epoch 94, Loss: 0.0455
# Epoch 95, Loss: 0.0450
# Epoch 96, Loss: 0.0455
# Epoch 97, Loss: 0.0452
# Epoch 98, Loss: 0.0455
# Epoch 99, Loss: 0.0452
# Epoch 100, Loss: 0.0449
# Epoch 101, Loss: 0.0450
# Epoch 102, Loss: 0.0448
# Epoch 103, Loss: 0.0448
# Epoch 104, Loss: 0.0451
# Epoch 105, Loss: 0.0449
# Epoch 106, Loss: 0.0445
# Epoch 107, Loss: 0.0444
# Epoch 108, Loss: 0.0445
# Epoch 109, Loss: 0.0446
# Epoch 110, Loss: 0.0446
# Epoch 111, Loss: 0.0449
# Epoch 112, Loss: 0.0447
# Epoch 113, Loss: 0.0446
# Epoch 114, Loss: 0.0453
# Epoch 115, Loss: 0.0450
# Epoch 116, Loss: 0.0445
# Epoch 117, Loss: 0.0443
# Epoch 118, Loss: 0.0443
# Epoch 119, Loss: 0.0445
# Epoch 120, Loss: 0.0441
# Epoch 121, Loss: 0.0444
# Epoch 122, Loss: 0.0438
# Epoch 123, Loss: 0.0441
# Epoch 124, Loss: 0.0442
# Epoch 125, Loss: 0.0440
# Epoch 126, Loss: 0.0441
# Epoch 127, Loss: 0.0436
# Epoch 128, Loss: 0.0441
# Epoch 129, Loss: 0.0438
# Epoch 130, Loss: 0.0439
# Epoch 131, Loss: 0.0437
# Epoch 132, Loss: 0.0440
# Epoch 133, Loss: 0.0438
# Epoch 134, Loss: 0.0437
# Epoch 135, Loss: 0.0439
# Epoch 136, Loss: 0.0438
# Epoch 137, Loss: 0.0440
# Epoch 138, Loss: 0.0441
# Epoch 139, Loss: 0.0436
# Epoch 140, Loss: 0.0443
# Epoch 141, Loss: 0.0435
# Epoch 142, Loss: 0.0439
# Epoch 143, Loss: 0.0441
# Epoch 144, Loss: 0.0439
# Epoch 145, Loss: 0.0435
# Epoch 146, Loss: 0.0441
# Epoch 147, Loss: 0.0438
# Epoch 148, Loss: 0.0437
# Epoch 149, Loss: 0.0437
# Epoch 150, Loss: 0.0437
# Epoch 151, Loss: 0.0436
# Epoch 152, Loss: 0.0434
# Epoch 153, Loss: 0.0438
# Epoch 154, Loss: 0.0433
# Epoch 155, Loss: 0.0437
# Epoch 156, Loss: 0.0430
# Epoch 157, Loss: 0.0439
# Epoch 158, Loss: 0.0433
# Epoch 159, Loss: 0.0432
# Epoch 160, Loss: 0.0436
# Epoch 161, Loss: 0.0430
# Epoch 162, Loss: 0.0437
# Epoch 163, Loss: 0.0431
# Epoch 164, Loss: 0.0428
# Epoch 165, Loss: 0.0430
# Epoch 166, Loss: 0.0432
# Epoch 167, Loss: 0.0432
# Epoch 168, Loss: 0.0429
# Epoch 169, Loss: 0.0433
# Epoch 170, Loss: 0.0435
# Epoch 171, Loss: 0.0434
# Epoch 172, Loss: 0.0431
# Epoch 173, Loss: 0.0432
# Epoch 174, Loss: 0.0430
# Epoch 175, Loss: 0.0431
# Epoch 176, Loss: 0.0434
# Epoch 177, Loss: 0.0433
# Epoch 178, Loss: 0.0426
# Epoch 179, Loss: 0.0432
# Epoch 180, Loss: 0.0430
# Epoch 181, Loss: 0.0431
# Epoch 182, Loss: 0.0426
# Epoch 183, Loss: 0.0427
# Epoch 184, Loss: 0.0428
# Epoch 185, Loss: 0.0423
# Epoch 186, Loss: 0.0431
# Epoch 187, Loss: 0.0430
# Epoch 188, Loss: 0.0438
# Epoch 189, Loss: 0.0434
# Epoch 190, Loss: 0.0433
# Epoch 191, Loss: 0.0429
# Epoch 192, Loss: 0.0430
# Epoch 193, Loss: 0.0434
# Epoch 194, Loss: 0.0432
# Epoch 195, Loss: 0.0433
# Epoch 196, Loss: 0.0437
# Epoch 197, Loss: 0.0429
# Epoch 198, Loss: 0.0429
# Epoch 199, Loss: 0.0428
# Epoch 200, Loss: 0.0431
# Epoch 201, Loss: 0.0433
# Epoch 202, Loss: 0.0429
# Epoch 203, Loss: 0.0431
# Epoch 204, Loss: 0.0432
# Epoch 205, Loss: 0.0430
# Epoch 206, Loss: 0.0423
# Epoch 207, Loss: 0.0435
# Epoch 208, Loss: 0.0433
# Epoch 209, Loss: 0.0431
# Epoch 210, Loss: 0.0422
# Epoch 211, Loss: 0.0425
# Epoch 212, Loss: 0.0426
# Epoch 213, Loss: 0.0424
# Epoch 214, Loss: 0.0427
# Epoch 215, Loss: 0.0426
# Epoch 216, Loss: 0.0427
# Epoch 217, Loss: 0.0425
# Epoch 218, Loss: 0.0431
# Epoch 219, Loss: 0.0425
# Epoch 220, Loss: 0.0425
# Epoch 221, Loss: 0.0425
# Epoch 222, Loss: 0.0428
# Epoch 223, Loss: 0.0426
# Epoch 224, Loss: 0.0429
# Epoch 225, Loss: 0.0430
# Epoch 226, Loss: 0.0421
# Epoch 227, Loss: 0.0431
# Epoch 228, Loss: 0.0426
# Epoch 229, Loss: 0.0425
# Epoch 230, Loss: 0.0427
# Epoch 231, Loss: 0.0423
# Epoch 232, Loss: 0.0428
# Epoch 233, Loss: 0.0420
# Epoch 234, Loss: 0.0424
# Epoch 235, Loss: 0.0428
# Epoch 236, Loss: 0.0431
# Epoch 237, Loss: 0.0425
# Epoch 238, Loss: 0.0426
# Epoch 239, Loss: 0.0422
# Epoch 240, Loss: 0.0425
# Epoch 241, Loss: 0.0424
# Epoch 242, Loss: 0.0425
# Epoch 243, Loss: 0.0425
# Epoch 244, Loss: 0.0424
# Epoch 245, Loss: 0.0426
# Epoch 246, Loss: 0.0424
# Epoch 247, Loss: 0.0422
# Epoch 248, Loss: 0.0427
# Epoch 249, Loss: 0.0424
# Epoch 250, Loss: 0.0425
# Epoch 251, Loss: 0.0424
# Epoch 252, Loss: 0.0428
# Epoch 253, Loss: 0.0426
# Epoch 254, Loss: 0.0427
# Epoch 255, Loss: 0.0422
# Epoch 256, Loss: 0.0426
# Epoch 257, Loss: 0.0424
# Epoch 258, Loss: 0.0426
# Epoch 259, Loss: 0.0424
# Epoch 260, Loss: 0.0425
# Epoch 261, Loss: 0.0425
# Epoch 262, Loss: 0.0426
# Epoch 263, Loss: 0.0426
# Epoch 264, Loss: 0.0429
# Epoch 265, Loss: 0.0422
# Epoch 266, Loss: 0.0427
# Epoch 267, Loss: 0.0425
# Epoch 268, Loss: 0.0423
# Epoch 269, Loss: 0.0424
# Epoch 270, Loss: 0.0421
# Epoch 271, Loss: 0.0420
# Epoch 272, Loss: 0.0424
# Epoch 273, Loss: 0.0424
# Epoch 274, Loss: 0.0422
# Epoch 275, Loss: 0.0428
# Epoch 276, Loss: 0.0424
# Epoch 277, Loss: 0.0427
# Epoch 278, Loss: 0.0427
# Epoch 279, Loss: 0.0423
# Epoch 280, Loss: 0.0421
# Epoch 281, Loss: 0.0423
# Epoch 282, Loss: 0.0428
# Epoch 283, Loss: 0.0425
# Epoch 284, Loss: 0.0428
# Epoch 285, Loss: 0.0430
# Epoch 286, Loss: 0.0426
# Epoch 287, Loss: 0.0423
# Epoch 288, Loss: 0.0428
# Epoch 289, Loss: 0.0427
# Epoch 290, Loss: 0.0424
# Epoch 291, Loss: 0.0424
# Epoch 292, Loss: 0.0421
# Epoch 293, Loss: 0.0421
# Epoch 294, Loss: 0.0431
# Epoch 295, Loss: 0.0426
# Epoch 296, Loss: 0.0428
# Epoch 297, Loss: 0.0425
# Epoch 298, Loss: 0.0424
# Epoch 299, Loss: 0.0427
# Epoch 300, Loss: 0.0426
# Epoch 301, Loss: 0.0430
# Epoch 302, Loss: 0.0423
# Epoch 303, Loss: 0.0431
# Epoch 304, Loss: 0.0425
# Epoch 305, Loss: 0.0423
# Epoch 306, Loss: 0.0428
# Epoch 307, Loss: 0.0426
# Epoch 308, Loss: 0.0426
# Epoch 309, Loss: 0.0422
# Epoch 310, Loss: 0.0421
# Epoch 311, Loss: 0.0424
# Epoch 312, Loss: 0.0423
# Epoch 313, Loss: 0.0426
# Epoch 314, Loss: 0.0424
# Epoch 315, Loss: 0.0422
# Epoch 316, Loss: 0.0425
# Epoch 317, Loss: 0.0424
# Epoch 318, Loss: 0.0426
# Epoch 319, Loss: 0.0422
# Epoch 320, Loss: 0.0428
# Epoch 321, Loss: 0.0425
# Epoch 322, Loss: 0.0427
# Epoch 323, Loss: 0.0423
# Epoch 324, Loss: 0.0429
# Epoch 325, Loss: 0.0423
# Epoch 326, Loss: 0.0425
# Epoch 327, Loss: 0.0424
# Epoch 328, Loss: 0.0429
# Epoch 329, Loss: 0.0422
# Epoch 330, Loss: 0.0426
# Epoch 331, Loss: 0.0427
# Epoch 332, Loss: 0.0422
# Epoch 333, Loss: 0.0424
# Epoch 334, Loss: 0.0428
# Epoch 335, Loss: 0.0426
# Epoch 336, Loss: 0.0430
# Epoch 337, Loss: 0.0419
# Epoch 338, Loss: 0.0425
# Epoch 339, Loss: 0.0425
# Epoch 340, Loss: 0.0422
# Epoch 341, Loss: 0.0427
# Epoch 342, Loss: 0.0424
# Epoch 343, Loss: 0.0423
# Epoch 344, Loss: 0.0421
# Epoch 345, Loss: 0.0422
# Epoch 346, Loss: 0.0423
# Epoch 347, Loss: 0.0424
# Epoch 348, Loss: 0.0423
# Epoch 349, Loss: 0.0422
# Epoch 350, Loss: 0.0423
# Epoch 351, Loss: 0.0423
# Epoch 352, Loss: 0.0429
# Epoch 353, Loss: 0.0422
# Epoch 354, Loss: 0.0423
# Epoch 355, Loss: 0.0427
# Epoch 356, Loss: 0.0422
# Epoch 357, Loss: 0.0424
# Epoch 358, Loss: 0.0425
# Epoch 359, Loss: 0.0425
# Epoch 360, Loss: 0.0426
# Epoch 361, Loss: 0.0426
# Epoch 362, Loss: 0.0424
# Epoch 363, Loss: 0.0423
# Epoch 364, Loss: 0.0425
# Epoch 365, Loss: 0.0421
# Epoch 366, Loss: 0.0424
# Epoch 367, Loss: 0.0425
# Epoch 368, Loss: 0.0420
# Epoch 369, Loss: 0.0422
# Epoch 370, Loss: 0.0422
# Epoch 371, Loss: 0.0422
# Epoch 372, Loss: 0.0422
# Epoch 373, Loss: 0.0425
# Epoch 374, Loss: 0.0428
# Epoch 375, Loss: 0.0422
# Epoch 376, Loss: 0.0420
# Epoch 377, Loss: 0.0423
# Epoch 378, Loss: 0.0428
# Epoch 379, Loss: 0.0420
# Epoch 380, Loss: 0.0418
# Epoch 381, Loss: 0.0421
# Epoch 382, Loss: 0.0420
# Epoch 383, Loss: 0.0422
# Epoch 384, Loss: 0.0421
# Epoch 385, Loss: 0.0427
# Epoch 386, Loss: 0.0421
# Epoch 387, Loss: 0.0421
# Epoch 388, Loss: 0.0428
# Epoch 389, Loss: 0.0423
# Epoch 390, Loss: 0.0426
# Epoch 391, Loss: 0.0422
# Epoch 392, Loss: 0.0427
# Epoch 393, Loss: 0.0421
# Epoch 394, Loss: 0.0423
# Epoch 395, Loss: 0.0421
# Epoch 396, Loss: 0.0423
# Epoch 397, Loss: 0.0429
# Epoch 398, Loss: 0.0423
# Epoch 399, Loss: 0.0424
# Epoch 400, Loss: 0.0421
# Epoch 401, Loss: 0.0421
# Epoch 402, Loss: 0.0424
# Epoch 403, Loss: 0.0421
# Epoch 404, Loss: 0.0422
# Epoch 405, Loss: 0.0420
# Epoch 406, Loss: 0.0421
# Epoch 407, Loss: 0.0424
# Epoch 408, Loss: 0.0426
# Epoch 409, Loss: 0.0425
# Epoch 410, Loss: 0.0424
# Epoch 411, Loss: 0.0423
# Epoch 412, Loss: 0.0421
# Epoch 413, Loss: 0.0422
# Epoch 414, Loss: 0.0424
# Epoch 415, Loss: 0.0421
# Epoch 416, Loss: 0.0424
# Epoch 417, Loss: 0.0424
# Epoch 418, Loss: 0.0426
# Epoch 419, Loss: 0.0425
# Epoch 420, Loss: 0.0428
# Epoch 421, Loss: 0.0423
# Epoch 422, Loss: 0.0422
# Epoch 423, Loss: 0.0424
# Epoch 424, Loss: 0.0426
# Epoch 425, Loss: 0.0428
# Epoch 426, Loss: 0.0423
# Epoch 427, Loss: 0.0423
# Epoch 428, Loss: 0.0422
# Epoch 429, Loss: 0.0425
# Epoch 430, Loss: 0.0422
# Epoch 431, Loss: 0.0424
# Epoch 432, Loss: 0.0422
# Epoch 433, Loss: 0.0425
# Epoch 434, Loss: 0.0423
# Epoch 435, Loss: 0.0423
# Epoch 436, Loss: 0.0426
# Epoch 437, Loss: 0.0421
# Epoch 438, Loss: 0.0420
# Epoch 439, Loss: 0.0424
# Epoch 440, Loss: 0.0416
# Epoch 441, Loss: 0.0423
# Epoch 442, Loss: 0.0422
# Epoch 443, Loss: 0.0418
# Epoch 444, Loss: 0.0422
# Epoch 445, Loss: 0.0423
# Epoch 446, Loss: 0.0418
# Epoch 447, Loss: 0.0419
# Epoch 448, Loss: 0.0424
# Epoch 449, Loss: 0.0423
# Epoch 450, Loss: 0.0424
# Epoch 451, Loss: 0.0424
# Epoch 452, Loss: 0.0422
# Epoch 453, Loss: 0.0426
# Epoch 454, Loss: 0.0424
# Epoch 455, Loss: 0.0420
# Epoch 456, Loss: 0.0423
# Epoch 457, Loss: 0.0424
# Epoch 458, Loss: 0.0420
# Epoch 459, Loss: 0.0421
# Epoch 460, Loss: 0.0423
# Epoch 461, Loss: 0.0420
# Epoch 462, Loss: 0.0425
# Epoch 463, Loss: 0.0421
# Epoch 464, Loss: 0.0426
# Epoch 465, Loss: 0.0424
# Epoch 466, Loss: 0.0423
# Epoch 467, Loss: 0.0422
# Epoch 468, Loss: 0.0421
# Epoch 469, Loss: 0.0423
# Epoch 470, Loss: 0.0422
# Epoch 471, Loss: 0.0418
# Epoch 472, Loss: 0.0420
# Epoch 473, Loss: 0.0422
# Epoch 474, Loss: 0.0422
# Epoch 475, Loss: 0.0423
# Epoch 476, Loss: 0.0418
# Epoch 477, Loss: 0.0423
# Epoch 478, Loss: 0.0419
# Epoch 479, Loss: 0.0423
# Epoch 480, Loss: 0.0421
# Epoch 481, Loss: 0.0424
# Epoch 482, Loss: 0.0423
# Epoch 483, Loss: 0.0422
# Epoch 484, Loss: 0.0422
# Epoch 485, Loss: 0.0422
# Epoch 486, Loss: 0.0424
# Epoch 487, Loss: 0.0422
# Epoch 488, Loss: 0.0423
# Epoch 489, Loss: 0.0421
# Epoch 490, Loss: 0.0423
# Epoch 491, Loss: 0.0427
# Epoch 492, Loss: 0.0425
# Epoch 493, Loss: 0.0423
# Epoch 494, Loss: 0.0426
# Epoch 495, Loss: 0.0422
# Epoch 496, Loss: 0.0425
# Epoch 497, Loss: 0.0422
# Epoch 498, Loss: 0.0421
# Epoch 499, Loss: 0.0420
# Epoch 500, Loss: 0.0422
# Epoch 501, Loss: 0.0424
# Epoch 502, Loss: 0.0422
# Epoch 503, Loss: 0.0425
# Epoch 504, Loss: 0.0425
# Epoch 505, Loss: 0.0423
# Epoch 506, Loss: 0.0422
# Epoch 507, Loss: 0.0421
# Epoch 508, Loss: 0.0425
# Epoch 509, Loss: 0.0422
# Epoch 510, Loss: 0.0423
# Epoch 511, Loss: 0.0421
# Epoch 512, Loss: 0.0419
# Epoch 513, Loss: 0.0421
# Epoch 514, Loss: 0.0417
# Epoch 515, Loss: 0.0424
# Epoch 516, Loss: 0.0426
# Epoch 517, Loss: 0.0426
# Epoch 518, Loss: 0.0420
# Epoch 519, Loss: 0.0426
# Epoch 520, Loss: 0.0426
# Epoch 521, Loss: 0.0428
# Epoch 522, Loss: 0.0428
# Epoch 523, Loss: 0.0422
# Epoch 524, Loss: 0.0418
# Epoch 525, Loss: 0.0421
# Epoch 526, Loss: 0.0424
# Epoch 527, Loss: 0.0424
# Epoch 528, Loss: 0.0426
# Epoch 529, Loss: 0.0424
# Epoch 530, Loss: 0.0422
# Epoch 531, Loss: 0.0423
# Epoch 532, Loss: 0.0425
# Epoch 533, Loss: 0.0420
# Epoch 534, Loss: 0.0424
# Epoch 535, Loss: 0.0423
# Epoch 536, Loss: 0.0422
# Epoch 537, Loss: 0.0423
# Epoch 538, Loss: 0.0420
# Epoch 539, Loss: 0.0418
# Epoch 540, Loss: 0.0421
# Epoch 541, Loss: 0.0425
# Epoch 542, Loss: 0.0422
# Epoch 543, Loss: 0.0426
# Epoch 544, Loss: 0.0427
# Epoch 545, Loss: 0.0425
# Epoch 546, Loss: 0.0421
# Epoch 547, Loss: 0.0420
# Epoch 548, Loss: 0.0428
# Epoch 549, Loss: 0.0419
# Epoch 550, Loss: 0.0428
# Epoch 551, Loss: 0.0418
# Epoch 552, Loss: 0.0425
# Epoch 553, Loss: 0.0421
# Epoch 554, Loss: 0.0425
# Epoch 555, Loss: 0.0423
# Epoch 556, Loss: 0.0419
# Epoch 557, Loss: 0.0426
# Epoch 558, Loss: 0.0420
# Epoch 559, Loss: 0.0422
# Epoch 560, Loss: 0.0423
# Epoch 561, Loss: 0.0420
# Epoch 562, Loss: 0.0424
# Epoch 563, Loss: 0.0423
# Epoch 564, Loss: 0.0420
# Epoch 565, Loss: 0.0419
# Epoch 566, Loss: 0.0419
# Epoch 567, Loss: 0.0422
# Epoch 568, Loss: 0.0421
# Epoch 569, Loss: 0.0422
# Epoch 570, Loss: 0.0420
# Epoch 571, Loss: 0.0416
# Epoch 572, Loss: 0.0425
# Epoch 573, Loss: 0.0421
# Epoch 574, Loss: 0.0419
# Epoch 575, Loss: 0.0426
# Epoch 576, Loss: 0.0418
# Epoch 577, Loss: 0.0420
# Epoch 578, Loss: 0.0419
# Epoch 579, Loss: 0.0422
# Epoch 580, Loss: 0.0419
# Epoch 581, Loss: 0.0426
# Epoch 582, Loss: 0.0421
# Epoch 583, Loss: 0.0422
# Epoch 584, Loss: 0.0425
# Epoch 585, Loss: 0.0427
# Epoch 586, Loss: 0.0422
# Epoch 587, Loss: 0.0424
# Epoch 588, Loss: 0.0427
# Epoch 589, Loss: 0.0425
# Epoch 590, Loss: 0.0423
# Epoch 591, Loss: 0.0425
# Epoch 592, Loss: 0.0424
# Epoch 593, Loss: 0.0422
# Epoch 594, Loss: 0.0423
# Epoch 595, Loss: 0.0422
# Epoch 596, Loss: 0.0425
# Epoch 597, Loss: 0.0428
# Epoch 598, Loss: 0.0421
# Epoch 599, Loss: 0.0422
# Epoch 600, Loss: 0.0422
# Epoch 601, Loss: 0.0419
# Epoch 602, Loss: 0.0424
# Epoch 603, Loss: 0.0422
# Epoch 604, Loss: 0.0424
# Epoch 605, Loss: 0.0423
# Epoch 606, Loss: 0.0423
# Epoch 607, Loss: 0.0419
# Epoch 608, Loss: 0.0422
# Epoch 609, Loss: 0.0421
# Epoch 610, Loss: 0.0420
# Epoch 611, Loss: 0.0423
# Epoch 612, Loss: 0.0423
# Epoch 613, Loss: 0.0428
# Epoch 614, Loss: 0.0424
# Epoch 615, Loss: 0.0424
# Epoch 616, Loss: 0.0421
# Epoch 617, Loss: 0.0424
# Epoch 618, Loss: 0.0422
# Epoch 619, Loss: 0.0419
# Epoch 620, Loss: 0.0424
# Epoch 621, Loss: 0.0422
# Epoch 622, Loss: 0.0424
# Epoch 623, Loss: 0.0421
# Epoch 624, Loss: 0.0419
# Epoch 625, Loss: 0.0426
# Epoch 626, Loss: 0.0425
# Epoch 627, Loss: 0.0424
# Epoch 628, Loss: 0.0422
# Epoch 629, Loss: 0.0425
# Epoch 630, Loss: 0.0418
# Epoch 631, Loss: 0.0423
# Epoch 632, Loss: 0.0420
# Epoch 633, Loss: 0.0424
# Epoch 634, Loss: 0.0422
# Epoch 635, Loss: 0.0427
# Epoch 636, Loss: 0.0425
# Epoch 637, Loss: 0.0419
# Epoch 638, Loss: 0.0422
# Epoch 639, Loss: 0.0426
# Epoch 640, Loss: 0.0423
# Epoch 641, Loss: 0.0421
# Epoch 642, Loss: 0.0421
# Epoch 643, Loss: 0.0426
# Epoch 644, Loss: 0.0423
# Epoch 645, Loss: 0.0421
# Epoch 646, Loss: 0.0421
# Epoch 647, Loss: 0.0423
# Epoch 648, Loss: 0.0422
# Epoch 649, Loss: 0.0423
# Epoch 650, Loss: 0.0422
# Epoch 651, Loss: 0.0420
# Epoch 652, Loss: 0.0422
# Epoch 653, Loss: 0.0422
# Epoch 654, Loss: 0.0421
# Epoch 655, Loss: 0.0422
# Epoch 656, Loss: 0.0420
# Epoch 657, Loss: 0.0421
# Epoch 658, Loss: 0.0424
# Epoch 659, Loss: 0.0422
# Epoch 660, Loss: 0.0421
# Epoch 661, Loss: 0.0423
# Epoch 662, Loss: 0.0425
# Epoch 663, Loss: 0.0423
# Epoch 664, Loss: 0.0418
# Epoch 665, Loss: 0.0426
# Epoch 666, Loss: 0.0431
# Epoch 667, Loss: 0.0425
# Epoch 668, Loss: 0.0423
# Epoch 669, Loss: 0.0419
# Epoch 670, Loss: 0.0418
# Epoch 671, Loss: 0.0421
# Epoch 672, Loss: 0.0423
# Epoch 673, Loss: 0.0420
# Epoch 674, Loss: 0.0423
# Epoch 675, Loss: 0.0422
# Epoch 676, Loss: 0.0420
# Epoch 677, Loss: 0.0423
# Epoch 678, Loss: 0.0426
# Epoch 679, Loss: 0.0421
# Epoch 680, Loss: 0.0421
# Epoch 681, Loss: 0.0427
# Epoch 682, Loss: 0.0420
# Epoch 683, Loss: 0.0422
# Epoch 684, Loss: 0.0423
# Epoch 685, Loss: 0.0422
# Epoch 686, Loss: 0.0421
# Epoch 687, Loss: 0.0421
# Epoch 688, Loss: 0.0419
# Epoch 689, Loss: 0.0419
# Epoch 690, Loss: 0.0420
# Epoch 691, Loss: 0.0417
# Epoch 692, Loss: 0.0425
# Epoch 693, Loss: 0.0428
# Epoch 694, Loss: 0.0426
# Epoch 695, Loss: 0.0423
# Epoch 696, Loss: 0.0427
# Epoch 697, Loss: 0.0425
# Epoch 698, Loss: 0.0424
# Epoch 699, Loss: 0.0419
# Epoch 700, Loss: 0.0423
# Epoch 701, Loss: 0.0420
# Epoch 702, Loss: 0.0420
# Epoch 703, Loss: 0.0423
# Epoch 704, Loss: 0.0422
# Epoch 705, Loss: 0.0421
# Epoch 706, Loss: 0.0419
# Epoch 707, Loss: 0.0419
# Epoch 708, Loss: 0.0424
# Epoch 709, Loss: 0.0423
# Epoch 710, Loss: 0.0424
# Epoch 711, Loss: 0.0423
# Epoch 712, Loss: 0.0425
# Epoch 713, Loss: 0.0420
# Epoch 714, Loss: 0.0418
# Epoch 715, Loss: 0.0422
# Epoch 716, Loss: 0.0419
# Epoch 717, Loss: 0.0418
# Epoch 718, Loss: 0.0423
# Epoch 719, Loss: 0.0423
# Epoch 720, Loss: 0.0422
# Epoch 721, Loss: 0.0424
# Epoch 722, Loss: 0.0420
# Epoch 723, Loss: 0.0428
# Epoch 724, Loss: 0.0421
# Epoch 725, Loss: 0.0425
# Epoch 726, Loss: 0.0424
# Epoch 727, Loss: 0.0421
# Epoch 728, Loss: 0.0422
# Epoch 729, Loss: 0.0421
# Epoch 730, Loss: 0.0424
# Epoch 731, Loss: 0.0422
# Epoch 732, Loss: 0.0423
# Epoch 733, Loss: 0.0424
# Epoch 734, Loss: 0.0421
# Epoch 735, Loss: 0.0419
# Epoch 736, Loss: 0.0420
# Epoch 737, Loss: 0.0421
# Epoch 738, Loss: 0.0420
# Epoch 739, Loss: 0.0424
# Epoch 740, Loss: 0.0421
# Epoch 741, Loss: 0.0424
# Epoch 742, Loss: 0.0424
# Epoch 743, Loss: 0.0421
# Epoch 744, Loss: 0.0420
# Epoch 745, Loss: 0.0421
# Epoch 746, Loss: 0.0422
# Epoch 747, Loss: 0.0419
# Epoch 748, Loss: 0.0427
# Epoch 749, Loss: 0.0423
# Epoch 750, Loss: 0.0422
# Epoch 751, Loss: 0.0421
# Epoch 752, Loss: 0.0426
# Epoch 753, Loss: 0.0426
# Epoch 754, Loss: 0.0424
# Epoch 755, Loss: 0.0424
# Epoch 756, Loss: 0.0422
# Epoch 757, Loss: 0.0420
# Epoch 758, Loss: 0.0422
# Epoch 759, Loss: 0.0422
# Epoch 760, Loss: 0.0424
# Epoch 761, Loss: 0.0419
# Epoch 762, Loss: 0.0425
# Epoch 763, Loss: 0.0423
# Epoch 764, Loss: 0.0428
# Epoch 765, Loss: 0.0423
# Epoch 766, Loss: 0.0425
# Epoch 767, Loss: 0.0421
# Epoch 768, Loss: 0.0422
# Epoch 769, Loss: 0.0422
# Epoch 770, Loss: 0.0418
# Epoch 771, Loss: 0.0424
# Epoch 772, Loss: 0.0423
# Epoch 773, Loss: 0.0420
# Epoch 774, Loss: 0.0421
# Epoch 775, Loss: 0.0421
# Epoch 776, Loss: 0.0420
# Epoch 777, Loss: 0.0420
# Epoch 778, Loss: 0.0423
# Epoch 779, Loss: 0.0420
# Epoch 780, Loss: 0.0420
# Epoch 781, Loss: 0.0419
# Epoch 782, Loss: 0.0415
# Epoch 783, Loss: 0.0423
# Epoch 784, Loss: 0.0420
# Epoch 785, Loss: 0.0420
# Epoch 786, Loss: 0.0420
# Epoch 787, Loss: 0.0416
# Epoch 788, Loss: 0.0419
# Epoch 789, Loss: 0.0421
# Epoch 790, Loss: 0.0424
# Epoch 791, Loss: 0.0426
# Epoch 792, Loss: 0.0421
# Epoch 793, Loss: 0.0425
# Epoch 794, Loss: 0.0424
# Epoch 795, Loss: 0.0420
# Epoch 796, Loss: 0.0422
# Epoch 797, Loss: 0.0423
# Epoch 798, Loss: 0.0420
# Epoch 799, Loss: 0.0420
# Epoch 800, Loss: 0.0421
# Epoch 801, Loss: 0.0421
# Epoch 802, Loss: 0.0418
# Epoch 803, Loss: 0.0419
# Epoch 804, Loss: 0.0423
# Epoch 805, Loss: 0.0425
# Epoch 806, Loss: 0.0424
# Epoch 807, Loss: 0.0421
# Epoch 808, Loss: 0.0423
# Epoch 809, Loss: 0.0420
# Epoch 810, Loss: 0.0427
# Epoch 811, Loss: 0.0420
# Epoch 812, Loss: 0.0424
# Epoch 813, Loss: 0.0425
# Epoch 814, Loss: 0.0422
# Epoch 815, Loss: 0.0422
# Epoch 816, Loss: 0.0423
# Epoch 817, Loss: 0.0423
# Epoch 818, Loss: 0.0424
# Epoch 819, Loss: 0.0417
# Epoch 820, Loss: 0.0424
# Epoch 821, Loss: 0.0421
# Epoch 822, Loss: 0.0421
# Epoch 823, Loss: 0.0418
# Epoch 824, Loss: 0.0421
# Epoch 825, Loss: 0.0419
# Epoch 826, Loss: 0.0423
# Epoch 827, Loss: 0.0420
# Epoch 828, Loss: 0.0420
# Epoch 829, Loss: 0.0420
# Epoch 830, Loss: 0.0421
# Epoch 831, Loss: 0.0422
# Epoch 832, Loss: 0.0418
# Epoch 833, Loss: 0.0421
# Epoch 834, Loss: 0.0421
# Epoch 835, Loss: 0.0419
# Epoch 836, Loss: 0.0427
# Epoch 837, Loss: 0.0423
# Epoch 838, Loss: 0.0421
# Epoch 839, Loss: 0.0423
# Epoch 840, Loss: 0.0422
# Epoch 841, Loss: 0.0418
# Epoch 842, Loss: 0.0424
# Epoch 843, Loss: 0.0422
# Epoch 844, Loss: 0.0419
# Epoch 845, Loss: 0.0422
# Epoch 846, Loss: 0.0420
# Epoch 847, Loss: 0.0422
# Epoch 848, Loss: 0.0423
# Epoch 849, Loss: 0.0421
# Epoch 850, Loss: 0.0420
# Epoch 851, Loss: 0.0418
# Epoch 852, Loss: 0.0422
# Epoch 853, Loss: 0.0421
# Epoch 854, Loss: 0.0422
# Epoch 855, Loss: 0.0425
# Epoch 856, Loss: 0.0425
# Epoch 857, Loss: 0.0421
# Epoch 858, Loss: 0.0421
# Epoch 859, Loss: 0.0418
# Epoch 860, Loss: 0.0418
# Epoch 861, Loss: 0.0419
# Epoch 862, Loss: 0.0421
# Epoch 863, Loss: 0.0420
# Epoch 864, Loss: 0.0421
# Epoch 865, Loss: 0.0422
# Epoch 866, Loss: 0.0421
# Epoch 867, Loss: 0.0422
# Epoch 868, Loss: 0.0419
# Epoch 869, Loss: 0.0422
# Epoch 870, Loss: 0.0421
# Epoch 871, Loss: 0.0422
# Epoch 872, Loss: 0.0416
# Epoch 873, Loss: 0.0424
# Epoch 874, Loss: 0.0420
# Epoch 875, Loss: 0.0423
# Epoch 876, Loss: 0.0421
# Epoch 877, Loss: 0.0422
# Epoch 878, Loss: 0.0423
# Epoch 879, Loss: 0.0420
# Epoch 880, Loss: 0.0421
# Epoch 881, Loss: 0.0421
# Epoch 882, Loss: 0.0422
# Epoch 883, Loss: 0.0421
# Epoch 884, Loss: 0.0417
# Epoch 885, Loss: 0.0425
# Epoch 886, Loss: 0.0420
# Epoch 887, Loss: 0.0420
# Epoch 888, Loss: 0.0422
# Epoch 889, Loss: 0.0422
# Epoch 890, Loss: 0.0421
# Epoch 891, Loss: 0.0424
# Epoch 892, Loss: 0.0423
# Epoch 893, Loss: 0.0421
# Epoch 894, Loss: 0.0418
# Epoch 895, Loss: 0.0419
# Epoch 896, Loss: 0.0418
# Epoch 897, Loss: 0.0419
# Epoch 898, Loss: 0.0420
# Epoch 899, Loss: 0.0421
# Epoch 900, Loss: 0.0420
# Epoch 901, Loss: 0.0419
# Epoch 902, Loss: 0.0424
# Epoch 903, Loss: 0.0417
# Epoch 904, Loss: 0.0421
# Epoch 905, Loss: 0.0423
# Epoch 906, Loss: 0.0421
# Epoch 907, Loss: 0.0422
# Epoch 908, Loss: 0.0424
# Epoch 909, Loss: 0.0420
# Epoch 910, Loss: 0.0420
# Epoch 911, Loss: 0.0421
# Epoch 912, Loss: 0.0420
# Epoch 913, Loss: 0.0426
# Epoch 914, Loss: 0.0421
# Epoch 915, Loss: 0.0424
# Epoch 916, Loss: 0.0423
# Epoch 917, Loss: 0.0427
# Epoch 918, Loss: 0.0427
# Epoch 919, Loss: 0.0422
# Epoch 920, Loss: 0.0426
# Epoch 921, Loss: 0.0423
# Epoch 922, Loss: 0.0419
# Epoch 923, Loss: 0.0422
# Epoch 924, Loss: 0.0418
# Epoch 925, Loss: 0.0420
# Epoch 926, Loss: 0.0421
# Epoch 927, Loss: 0.0416
# Epoch 928, Loss: 0.0420
# Epoch 929, Loss: 0.0422
# Epoch 930, Loss: 0.0418
# Epoch 931, Loss: 0.0416
# Epoch 932, Loss: 0.0421
# Epoch 933, Loss: 0.0422
# Epoch 934, Loss: 0.0421
# Epoch 935, Loss: 0.0421
# Epoch 936, Loss: 0.0421
# Epoch 937, Loss: 0.0421
# Epoch 938, Loss: 0.0419
# Epoch 939, Loss: 0.0421
# Epoch 940, Loss: 0.0419
# Epoch 941, Loss: 0.0420
# Epoch 942, Loss: 0.0420
# Epoch 943, Loss: 0.0420
# Epoch 944, Loss: 0.0421
# Epoch 945, Loss: 0.0420
# Epoch 946, Loss: 0.0420
# Epoch 947, Loss: 0.0419
# Epoch 948, Loss: 0.0420
# Epoch 949, Loss: 0.0421
# Epoch 950, Loss: 0.0423
# Epoch 951, Loss: 0.0417
# Epoch 952, Loss: 0.0420
# Epoch 953, Loss: 0.0421
# Epoch 954, Loss: 0.0422
# Epoch 955, Loss: 0.0420
# Epoch 956, Loss: 0.0420
# Epoch 957, Loss: 0.0419
# Epoch 958, Loss: 0.0419
# Epoch 959, Loss: 0.0422
# Epoch 960, Loss: 0.0421
# Epoch 961, Loss: 0.0420
# Epoch 962, Loss: 0.0420
# Epoch 963, Loss: 0.0422
# Epoch 964, Loss: 0.0420
# Epoch 965, Loss: 0.0418
# Epoch 966, Loss: 0.0418
# Epoch 967, Loss: 0.0424
# Epoch 968, Loss: 0.0418
# Epoch 969, Loss: 0.0420
# Epoch 970, Loss: 0.0421
# Epoch 971, Loss: 0.0421
# Epoch 972, Loss: 0.0424
# Epoch 973, Loss: 0.0421
# Epoch 974, Loss: 0.0420
# Epoch 975, Loss: 0.0420
# Epoch 976, Loss: 0.0420
# Epoch 977, Loss: 0.0424
# Epoch 978, Loss: 0.0421
# Epoch 979, Loss: 0.0424
# Epoch 980, Loss: 0.0424
# Epoch 981, Loss: 0.0420
# Epoch 982, Loss: 0.0422
# Epoch 983, Loss: 0.0420
# Epoch 984, Loss: 0.0418
# Epoch 985, Loss: 0.0423
# Epoch 986, Loss: 0.0422
# Epoch 987, Loss: 0.0423
# Epoch 988, Loss: 0.0425
# Epoch 989, Loss: 0.0421
# Epoch 990, Loss: 0.0424
# Epoch 991, Loss: 0.0424
# Epoch 992, Loss: 0.0423
# Epoch 993, Loss: 0.0421
# Epoch 994, Loss: 0.0420
# Epoch 995, Loss: 0.0428
# Epoch 996, Loss: 0.0422
# Epoch 997, Loss: 0.0418
# Epoch 998, Loss: 0.0419
# Epoch 999, Loss: 0.0420
# Epoch 1000, Loss: 0.0420

# %%
seed = "To be, or not to be"
try:

    os.system('clear')


    temperature = np.random.uniform(0.5, 1.2)
    generated_text = generate_text(model, seed, length=200, temperature=temperature)

    print(f"Temperature: {temperature:.2f}")
    print(f"Generated text:\n{generated_text}")


    time.sleep(2)

except KeyboardInterrupt:
    print("\nStopping text generation...")
# Out:
# Temperature: 0.94
# Generated text:
# To be, or not to be, that is the question:
# Whether 'tis nobler in the mind to suffer
# The slings and arrows of outrageous fortune,
# Or to take Arms against a Sea of troubles...
# Whether 'tis nobler in the mind to suffer
# Th

# %% [markdown]
# # Implementation of LSTMs
#
# For simplicity, we will **generate** a sine wave dataset.

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

sequence_length = 50
num_epochs = 100
learning_rate = 0.001
input_size = 1
hidden_size = 128
num_layers = 2
output_size = 1

time_steps = np.linspace(0, 100, 1000)
data = np.sin(time_steps)

def create_sequences(data, sequence_length):
    xs, ys = [], []
    for i in range(len(data) - sequence_length):
        xs.append(data[i:i+sequence_length])
        ys.append(data[i+sequence_length])
    return np.array(xs), np.array(ys)

X, y = create_sequences(data, sequence_length)
X = torch.from_numpy(X).float().unsqueeze(-1)  # (batch_size, seq_length, input_size)
y = torch.from_numpy(y).float().unsqueeze(-1)  # (batch_size, output_size)

# Split into training and testing
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size

train_X, test_X = X[:train_size], X[train_size:]
train_y, test_y = y[:train_size], y[train_size:]

# %%
# Plot the generated sine wave dataset
plt.figure(figsize=(10, 5))
plt.plot(time_steps, data, label='Sine Wave')
plt.title('Generated Sine Wave Dataset')
plt.xlabel('Time Steps')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %% [markdown]
# # Model Definition

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])  # Take the last output
        return out

# Initialize the model, loss function, and optimizer
model = LSTMModel(input_size, hidden_size, num_layers, output_size)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Training the model
for epoch in range(num_epochs):
    model.train()
    outputs = model(train_X)
    optimizer.zero_grad()
    loss = criterion(outputs, train_y)
    loss.backward()
    optimizer.step()

    if (epoch+1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [10/100], Loss: 0.2932
# Epoch [20/100], Loss: 0.0782
# Epoch [30/100], Loss: 0.0136
# Epoch [40/100], Loss: 0.0026
# Epoch [50/100], Loss: 0.0016
# Epoch [60/100], Loss: 0.0005
# Epoch [70/100], Loss: 0.0002
# Epoch [80/100], Loss: 0.0001
# Epoch [90/100], Loss: 0.0001
# Epoch [100/100], Loss: 0.0001

# %%
# Plotting the dataset (sine wave) and LSTM predictions
plt.figure(figsize=(12, 6))

# Plot the actual sine wave (full dataset)
plt.plot(time_steps, data, label='Original Sine Wave', color='blue', alpha=0.6)

# Plot LSTM predictions (only for test data)
test_predict = model(test_X).detach().numpy()  # Get model predictions on test set
test_y_np = test_y.numpy()

# Shift predictions to align with the corresponding time steps in the plot
plt.plot(time_steps[-test_size:], test_predict, label='LSTM Predictions', color='red', alpha=0.8)

# Add labels and title
plt.title('LSTM Predictions vs Original Sine Wave')
plt.xlabel('Time Steps')
plt.ylabel('Amplitude')
plt.legend()

# Show the plot
plt.show()
